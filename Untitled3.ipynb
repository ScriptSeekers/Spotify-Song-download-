# %%
{
    "nbformat":4,
    "nbformat_minor":0,
    "metadata":{
        "colab":{
            "provenance":[],
            "authorship_tag":
            "ABX9TyPiehEY3tseU5EYL6kbSwCF"},
        "kernelspec":{"name":"python3",
                      "display_name":"Python 3"}
        ,"language_info":{"name":"python"}},
    "cells":[{"cell_type":"code",
              "execution_count":1,
              "metadata":{
                  "colab":{
                      "base_uri":"https://localhost:8080/"},
                  "id":"zMFyfhXfN8PK",
                  "executionInfo":{
                      "status":"ok",
                      "timestamp":1732268179092,
                      "user_tz":-330,
                      "elapsed":22869,
                      "user":{
                          "displayName":"Arpit Vishwakarma",
                          "userId":"03710693643150708099"}},
                  "outputId":"d5fcee36-9e1f-40b3-bfe7-b02f102ef7d5"},
              "outputs":[
                  {
                      "output_type":"stream",
                      "name":"stdout","text":[
                          "Collecting spotdl\n",
                          "  Downloading spotdl-4.2.10-py3-none-any.whl.metadata (8.4 kB)\n",
                          "Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from spotdl) (4.12.3)\n",
                          "Collecting fastapi<0.104.0,>=0.103.0 (from spotdl)\n",
                          "  Downloading fastapi-0.103.2-py3-none-any.whl.metadata (24 kB)\n",
                          "Collecting mutagen<2.0.0,>=1.47.0 (from spotdl)\n",
                          "  Downloading mutagen-1.47.0-py3-none-any.whl.metadata (1.7 kB)\n",
                          "Requirement already satisfied: platformdirs<5.0.0,>=4.3.6 in /usr/local/lib/python3.10/dist-packages (from spotdl) (4.3.6)\n",
                          "Requirement already satisfied: pydantic<3.0.0,>=2.9.2 in /usr/local/lib/python3.10/dist-packages (from spotdl) (2.9.2)\n",
                          "Collecting pykakasi<3.0.0,>=2.3.0 (from spotdl)\n",
                          "  Downloading pykakasi-2.3.0-py3-none-any.whl.metadata (5.9 kB)\n",
                          "Requirement already satisfied: python-slugify<9.0.0,>=8.0.4 in /usr/local/lib/python3.10/dist-packages (from python-slugify[unidecode]<9.0.0,>=8.0.4->spotdl) (8.0.4)\n",
                          "Collecting pytube<16.0.0,>=15.0.0 (from spotdl)\n",
                          "  Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)\n",
                          "Collecting rapidfuzz<4.0.0,>=3.10.1 (from spotdl)\n",
                          "  Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)\n",
                          "Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.10/dist-packages (from spotdl) (2.32.3)\n",
                          "Requirement already satisfied: rich<14.0.0,>=13.9.4 in /usr/local/lib/python3.10/dist-packages (from spotdl) (13.9.4)\n",
                          "Collecting soundcloud-v2<2.0.0,>=1.6.0 (from spotdl)\n",
                          "  Downloading soundcloud_v2-1.6.0-py3-none-any.whl.metadata (3.6 kB)\n",
                          "Collecting spotipy<3.0.0,>=2.24.0 (from spotdl)\n",
                          "  Downloading spotipy-2.24.0-py3-none-any.whl.metadata (4.9 kB)\n",
                          "Collecting syncedlyrics<2.0.0,>=1.0.1 (from spotdl)\n",
                          "  Downloading syncedlyrics-1.0.1-py3-none-any.whl.metadata (3.6 kB)\n",
                          "Collecting uvicorn<0.24.0,>=0.23.2 (from spotdl)\n",
                          "  Downloading uvicorn-0.23.2-py3-none-any.whl.metadata (6.2 kB)\n",
                          "Collecting websockets<15.0,>=14.1 (from spotdl)\n",
                          "  Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)\n",
                          "Collecting yt-dlp<2025.0.0,>=2024.11.18 (from spotdl)\n",
                          "  Downloading yt_dlp-2024.11.18-py3-none-any.whl.metadata (172 kB)\n",
                          "\u001b[2K     \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m172.1/172.1 kB\u001b[0m \u001b[31m5.6 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hCollecting ytmusicapi<2.0.0,>=1.4.1 (from spotdl)\n",
                          "  Downloading ytmusicapi-1.8.2-py3-none-any.whl.metadata (5.5 kB)\n",
                          "Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->spotdl) (2.6)\n",
                          "Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi<0.104.0,>=0.103.0->spotdl) (3.7.1)\n",
                          "Collecting starlette<0.28.0,>=0.27.0 (from fastapi<0.104.0,>=0.103.0->spotdl)\n",
                          "  Downloading starlette-0.27.0-py3-none-any.whl.metadata (5.8 kB)\n",
                          "Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from fastapi<0.104.0,>=0.103.0->spotdl) (4.12.2)\n",
                          "Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.9.2->spotdl) (0.7.0)\n",
                          "Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.9.2->spotdl) (2.23.4)\n",
                          "Collecting jaconv (from pykakasi<3.0.0,>=2.3.0->spotdl)\n",
                          "  Downloading jaconv-0.4.0.tar.gz (17 kB)\n",
                          "  Preparing metadata (setup.py) ... \u001b[?25l\u001b[?25hdone\n",
                          "Requirement already satisfied: deprecated in /usr/local/lib/python3.10/dist-packages (from pykakasi<3.0.0,>=2.3.0->spotdl) (1.2.15)\n",
                          "Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify<9.0.0,>=8.0.4->python-slugify[unidecode]<9.0.0,>=8.0.4->spotdl) (1.3)\n",
                          "Collecting Unidecode>=1.1.1 (from python-slugify[unidecode]<9.0.0,>=8.0.4->spotdl)\n",
                          "  Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)\n",
                          "Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->spotdl) (3.4.0)\n",
                          "Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->spotdl) (3.10)\n",
                          "Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->spotdl) (2.2.3)\n",
                          "Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->spotdl) (2024.8.30)\n",
                          "Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.9.4->spotdl) (3.0.0)\n",
                          "Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.9.4->spotdl) (2.18.0)\n",
                          "Collecting dacite>=1.8.1 (from soundcloud-v2<2.0.0,>=1.6.0->spotdl)\n","  Downloading dacite-1.8.1-py3-none-any.whl.metadata (15 kB)\n",
                          "Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from soundcloud-v2<2.0.0,>=1.6.0->spotdl) (2.8.2)\n",
                          "Collecting redis>=3.5.3 (from spotipy<3.0.0,>=2.24.0->spotdl)\n",
                          "  Downloading redis-5.2.0-py3-none-any.whl.metadata (9.1 kB)\n","Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn<0.24.0,>=0.23.2->spotdl) (8.1.7)\n",
                          "Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn<0.24.0,>=0.23.2->spotdl) (0.14.0)\n",
                          "Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi<0.104.0,>=0.103.0->spotdl) (1.3.1)\n",
                          "Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi<0.104.0,>=0.103.0->spotdl) (1.2.2)\n",
                          "Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.9.4->spotdl) (0.1.2)\n",
                          "Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->soundcloud-v2<2.0.0,>=1.6.0->spotdl) (1.16.0)\n",
                          "Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy<3.0.0,>=2.24.0->spotdl) (4.0.3)\n",
                          "Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->pykakasi<3.0.0,>=2.3.0->spotdl) (1.16.0)\n",
                          "Downloading spotdl-4.2.10-py3-none-any.whl (116 kB)\n","\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m116.2/116.2 kB\u001b[0m \u001b[31m6.9 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hDownloading fastapi-0.103.2-py3-none-any.whl (66 kB)\n",
                          "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m66.3/66.3 kB\u001b[0m \u001b[31m4.5 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hDownloading mutagen-1.47.0-py3-none-any.whl (194 kB)\n",
                          "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m194.4/194.4 kB\u001b[0m \u001b[31m12.8 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hDownloading pykakasi-2.3.0-py3-none-any.whl (2.4 MB)\n",
                          "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m2.4/2.4 MB\u001b[0m \u001b[31m47.0 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hDownloading pytube-15.0.0-py3-none-any.whl (57 kB)\n",
                          "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m57.6/57.6 kB\u001b[0m \u001b[31m3.0 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hDownloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)\n",
                          "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m3.1/3.1 MB\u001b[0m \u001b[31m56.0 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hDownloading soundcloud_v2-1.6.0-py3-none-any.whl (20 kB)\n",
                          "Downloading spotipy-2.24.0-py3-none-any.whl (30 kB)\n",
                          "Downloading syncedlyrics-1.0.1-py3-none-any.whl (17 kB)\n",
                          "Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)\n",
                          "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m59.5/59.5 kB\u001b[0m \u001b[31m3.9 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hDownloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168 kB)\n",
                          "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m168.2/168.2 kB\u001b[0m \u001b[31m11.3 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hDownloading yt_dlp-2024.11.18-py3-none-any.whl (3.2 MB)\n",
                          "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m3.2/3.2 MB\u001b[0m \u001b[31m67.2 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hDownloading ytmusicapi-1.8.2-py3-none-any.whl (87 kB)\n",
                          "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m87.8/87.8 kB\u001b[0m \u001b[31m6.6 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hDownloading dacite-1.8.1-py3-none-any.whl (14 kB)\n",
                          "Downloading redis-5.2.0-py3-none-any.whl (261 kB)\n",
                          "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m261.4/261.4 kB\u001b[0m \u001b[31m17.3 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hDownloading starlette-0.27.0-py3-none-any.whl (66 kB)\n",
                          "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m67.0/67.0 kB\u001b[0m \u001b[31m4.5 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hDownloading Unidecode-1.3.8-py3-none-any.whl (235 kB)\n",
                          "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m235.5/235.5 kB\u001b[0m \u001b[31m15.2 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
                          "\u001b[?25hBuilding wheels for collected packages: jaconv\n",
                          "  Building wheel for jaconv (setup.py) ... \u001b[?25l\u001b[?25hdone\n",
                          "  Created wheel for jaconv: filename=jaconv-0.4.0-py3-none-any.whl size=18229 sha256=5de26a7bef83a3bfb760df65d893e244d17059b3c7d86cd24294b7dbcde354d6\n",
                          "  Stored in directory: /root/.cache/pip/wheels/20/95/99/94e8d7545125181756857f6b1fc085ed4e0811ad9be7321af7\n",
                          "Successfully built jaconv\n",
                          "Installing collected packages: jaconv, yt-dlp, websockets, uvicorn, Unidecode, redis, rapidfuzz, pytube, mutagen, dacite, ytmusicapi, syncedlyrics, starlette, spotipy, soundcloud-v2, pykakasi, fastapi, spotdl\n",
                          "Successfully installed Unidecode-1.3.8 dacite-1.8.1 fastapi-0.103.2 jaconv-0.4.0 mutagen-1.47.0 pykakasi-2.3.0 pytube-15.0.0 rapidfuzz-3.10.1 redis-5.2.0 soundcloud-v2-1.6.0 spotdl-4.2.10 spotipy-2.24.0 starlette-0.27.0 syncedlyrics-1.0.1 uvicorn-0.23.2 websockets-14.1 yt-dlp-2024.11.18 ytmusicapi-1.8.2\n"
                          ]
                      }
                  ],
              "source":["!pip install spotdl"]
              }
             ,
              {
                  "cell_type":"code","source":["import os\n","def download_spotify_playlist(playlist_url,output_floder):\n",
                                               "  os.makedirs(output_floder,exist_ok=True)\n",
                                               "  command=f\"spotdl{playlist_url} -o {output_floder}\"\n",
                                               "  os.system(command)\n",
                                               "\n",
                                               "playlist_url=input(\"Enter the spotify playlist url:\")\n",
                                               "output_floder=input(\"Enter the output floder:\")\n",
                                               "download_spotify_playlist(playlist_url,output_floder)"
                                               ]
                  ,
                  "metadata":{
                              "colab":{
                                  "base_uri":"https://localhost:8080/"},
                              "id":"6qObIvFaPg5I",
                              "executionInfo":{
                                  "status":"ok",
                                  "timestamp":1732269111115,
                                  "user_tz":-330,
                                  "elapsed":65120,
                                  "user":
                                   {
                                       "displayName":"Arpit Vishwakarma",
                                       "userId":"03710693643150708099"
                                       }
                                  },
                              "outputId":"294ca741-7ccd-488c-f16a-33e97e4b8d82"
                              },
                  "execution_count":5,
                  "outputs":[
                      {"name":"stdout",
                       "output_type":"stream",
                       "text":[
                           "Enter the spotify playlist url:https://open.spotify.com/track/1OEmd2iXU8pWG7CrKNpGUg\n",
                           "Enter the output floder:https://open.spotify.com/track/1OEmd2iXU8pWG7CrKNpGUg\n"
                           ]
                       }
                      ]
                  }
             ]
    }
# Out:
# {'nbformat': 4,
#  'nbformat_minor': 0,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyPiehEY3tseU5EYL6kbSwCF'},
#   'kernelspec': {'name': 'python3', 'display_name': 'Python 3'},
#   'language_info': {'name': 'python'}},
#  'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'zMFyfhXfN8PK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1732268179092,
#      'user_tz': -330,
#      'elapsed': 22869,
#      'user': {'displayName': 'Arpit Vishwakarma',
#       'userId': '03710693643150708099'}},
#     'outputId': 'd5fcee36-9e1f-40b3-bfe7-b02f102ef7d5'},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': ['Collecting spotdl\n',
#       '  Downloading spotdl-4.2.10-py3-none-any.whl.metadata (8.4 kB)\n',
# ...
